# %% [markdown]
# <a href="https://colab.research.google.com/github/konoyuki2/Graduation_Research/blob/main/%E5%8D%92%E6%A5%AD%E7%A0%94%E7%A9%B62.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install japanize-matplotlib
import System

#2017final.map
#2017firstRound.map
#2017quarterFinal.map
#2017secondRound.map
#2017semiFinal.map
#2017vsBot3.map
client = Client('2017final.map')

# %%
flag = 0
flag2 = 0

while client.isWorking:
    value = client.get_ready()

    if flag == 0 and value[2] != 2:
        client.walk_up()
    elif flag == 1:
        client.look_right()
    elif flag == 2:
        client.look_down()
    elif flag == 3:
        client.look_left()
    elif flag == 4:
        client.look_up()
    elif flag == 5:
        client.search_right()
    elif flag == 6:
        client.search_down()
    elif flag == 7:
        client.search_left()
    elif flag == 8:
        client.search_up()
    elif flag == 9:
        client.put_down()
    elif flag == 10:
        client.put_left()
    elif flag == 11:
        client.put_up()
    elif flag == 13:
        client.put_right()
    elif value[2] == 1:
        client.put_up()
    elif value[4] == 1:
        client.put_left()
    elif value[6] == 1:
        client.put_right()
    elif value[8] == 1:
        client.put_down()
    elif value[6] == 3:
        client.walk_right()
    elif value[8] == 3:
        client.walk_down()
    elif value[4] == 3:
        client.walk_left()
    elif value[2] == 3:
        client.walk_up()
    elif value[6] != 2:
        flag2 = 0
        client.walk_right()
    elif value[8] != 2:
        client.walk_down()
    elif value[8] == 2 and flag2 == 0:
        client.look_down()
        flag2 += 1
    else:
        client.walk_up()

    flag += 1
